# %% [markdown]
# Just replace the standard dash.Dash class with the jupyter_dash.JupyterDash subclass.

# %%
# !pip install jupyter_dash
# Out:
# Collecting jupyter_dash
#   Downloading jupyter_dash-0.4.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: requests in /opt/python/envs/default/lib/python3.8/site-packages (from jupyter_dash) (2.25.1)
# Collecting ansi2html
#   Downloading ansi2html-1.6.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: ipykernel in /opt/python/envs/default/lib/python3.8/site-packages (from jupyter_dash) (5.5.3)
# Requirement already satisfied: ipython in /opt/python/envs/default/lib/python3.8/site-packages (from jupyter_dash) (7.22.0)
# Collecting flask
#   Downloading Flask-1.1.2-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 5.2 MB/s
# Requirement already satisfied: retrying in /opt/python/envs/default/lib/python3.8/site-packages (from jupyter_dash) (1.3.3)
# Collecting dash
#   Downloading dash-1.20.0.tar.gz (77 kB)
#      |████████████████████████████████| 77 kB 9.9 MB/s
# Collecting flask-compress
#   Downloading Flask_Compress-1.9.0-py3-none-any.whl (7.3 kB)
# Requirement already satisfied: plotly in /opt/python/envs/default/lib/python3.8/site-packages (from dash->jupyter_dash) (4.14.3)
# Collecting dash_renderer==1.9.1
#   Downloading dash_renderer-1.9.1.tar.gz (1.0 MB)
#      |████████████████████████████████| 1.0 MB 33.5 MB/s
# Collecting dash-core-components==1.16.0
#   Downloading dash_core_components-1.16.0.tar.gz (3.5 MB)
#      |████████████████████████████████| 3.5 MB 18.6 MB/s
# Collecting dash-html-components==1.1.3
#   Downloading dash_html_components-1.1.3.tar.gz (82 kB)
#      |████████████████████████████████| 82 kB 1.2 MB/s
# Collecting dash-table==4.11.3
#   Downloading dash_table-4.11.3.tar.gz (1.8 MB)
#      |████████████████████████████████| 1.8 MB 35.8 MB/s
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 31.4 MB/s
# Requirement already satisfied: Jinja2>=2.10.1 in /opt/python/envs/default/lib/python3.8/site-packages (from flask->jupyter_dash) (2.11.3)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: Werkzeug>=0.15 in /opt/python/envs/default/lib/python3.8/site-packages (from flask->jupyter_dash) (1.0.1)
# Requirement already satisfied: click>=5.1 in /opt/python/envs/default/lib/python3.8/site-packages (from flask->jupyter_dash) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/python/envs/default/lib/python3.8/site-packages (from Jinja2>=2.10.1->flask->jupyter_dash) (1.1.1)
# Collecting brotli
#   Downloading Brotli-1.0.9-cp38-cp38-manylinux1_x86_64.whl (357 kB)
#      |████████████████████████████████| 357 kB 44.2 MB/s
# Requirement already satisfied: jupyter-client in /opt/python/envs/default/lib/python3.8/site-packages (from ipykernel->jupyter_dash) (6.1.12)
# Requirement already satisfied: traitlets>=4.1.0 in /opt/python/envs/default/lib/python3.8/site-packages (from ipykernel->jupyter_dash) (5.0.5)
# Requirement already satisfied: tornado>=4.2 in /opt/python/envs/default/lib/python3.8/site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: pexpect>4.3 in /opt/python/envs/default/lib/python3.8/site-packages (from ipython->jupyter_dash) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /opt/python/envs/default/lib/python3.8/site-packages (from ipython->jupyter_dash) (49.2.1)
# Requirement already satisfied: backcall in /opt/python/envs/default/lib/python3.8/site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: pickleshare in /opt/python/envs/default/lib/python3.8/site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/python/envs/default/lib/python3.8/site-packages (from ipython->jupyter_dash) (3.0.18)
# Requirement already satisfied: decorator in /opt/python/envs/default/lib/python3.8/site-packages (from ipython->jupyter_dash) (4.4.2)
# Requirement already satisfied: pygments in /opt/python/envs/default/lib/python3.8/site-packages (from ipython->jupyter_dash) (2.8.1)
# Requirement already satisfied: jedi>=0.16 in /opt/python/envs/default/lib/python3.8/site-packages (from ipython->jupyter_dash) (0.17.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /opt/python/envs/default/lib/python3.8/site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/python/envs/default/lib/python3.8/site-packages (from pexpect>4.3->ipython->jupyter_dash) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/python/envs/default/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: ipython-genutils in /opt/python/envs/default/lib/python3.8/site-packages (from traitlets>=4.1.0->ipykernel->jupyter_dash) (0.2.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /opt/python/envs/default/lib/python3.8/site-packages (from jupyter-client->ipykernel->jupyter_dash) (4.7.1)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/python/envs/default/lib/python3.8/site-packages (from jupyter-client->ipykernel->jupyter_dash) (2.8.1)
# Requirement already satisfied: pyzmq>=13 in /opt/python/envs/default/lib/python3.8/site-packages (from jupyter-client->ipykernel->jupyter_dash) (22.0.3)
# Requirement already satisfied: six>=1.5 in /opt/python/envs/default/lib/python3.8/site-packages (from python-dateutil>=2.1->jupyter-client->ipykernel->jupyter_dash) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/python/envs/default/lib/python3.8/site-packages (from requests->jupyter_dash) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/python/envs/default/lib/python3.8/site-packages (from requests->jupyter_dash) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/python/envs/default/lib/python3.8/site-packages (from requests->jupyter_dash) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/python/envs/default/lib/python3.8/site-packages (from requests->jupyter_dash) (1.26.4)
# Building wheels for collected packages: dash, dash-core-components, dash-html-components, dash-renderer, dash-table, future
# done
#   Created wheel for dash: filename=dash-1.20.0-py3-none-any.whl size=85831 sha256=9df95879b4464b143f8a118f7d8e458f35eb0d4e73074d449169eaa6a59fd4e8
#   Stored in directory: /home/datalore/.cache/pip/wheels/e3/1e/fa/0c810b67f082a7b9f33a128f6374b03cf5245edc45e37adbf8
# done
#   Created wheel for dash-core-components: filename=dash_core_components-1.16.0-py3-none-any.whl size=3540991 sha256=c2d5e9c5d2baf7141736bd3ddd1f18ff0418d5ee2f127aad8397ba9d58a672a7
#   Stored in directory: /home/datalore/.cache/pip/wheels/68/92/0c/4ac6d91639a754ebf3adfab7172c61fe408e7c71d00b8cbf66
# done
#   Created wheel for dash-html-components: filename=dash_html_components-1.1.3-py3-none-any.whl size=319471 sha256=5337fcb227987f77633eda0c5df0de335b7a2eb1c0a1df109fcda54b8a06ee6d
#   Stored in directory: /home/datalore/.cache/pip/wheels/2a/a3/33/bf6842d5d279588f8989ee8c2f9d9d8feb7af82216493a1eea
# done
#   Created wheel for dash-renderer: filename=dash_renderer-1.9.1-py3-none-any.whl size=1014878 sha256=08d51dc689b3d8184222d24805133513002bdfd76690cd1b9267368c371a04df
#   Stored in directory: /home/datalore/.cache/pip/wheels/ac/7e/fd/807844722d79d8babcd27b16e5f7ecc7b476c45ca607c11729
# done
#   Created wheel for dash-table: filename=dash_table-4.11.3-py3-none-any.whl size=1827618 sha256=0f85c666162604c870910323e79ef9ab81fa95057db95c487deced4f387a6b46
#   Stored in directory: /home/datalore/.cache/pip/wheels/0c/9c/bd/06904831bdaa998ad1f53584553c5e06324814328666699128
# done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491059 sha256=8d9e25d5f766d99adeceb61ab3c42551e8df9d2b4ec2a84731f768fd04b43928
#   Stored in directory: /home/datalore/.cache/pip/wheels/8e/70/28/3d6ccd6e315f65f245da085482a2e1c7d14b90b30f239e2cf4
# Successfully built dash dash-core-components dash-html-components dash-renderer dash-table future
# Installing collected packages: itsdangerous, flask, brotli, future, flask-compress, dash-table, dash-renderer, dash-html-components, dash-core-components, dash, ansi2html, jupyter-dash
# Successfully installed ansi2html-1.6.0 brotli-1.0.9 dash-1.20.0 dash-core-components-1.16.0 dash-html-components-1.1.3 dash-renderer-1.9.1 dash-table-4.11.3 flask-1.1.2 flask-compress-1.9.0 future-0.18.2 itsdangerous-1.1.0 jupyter-dash-0.4.0
# WARNING: You are using pip version 21.0.1; however, version 21.1 is available.
# You should consider upgrading via the '/opt/python/envs/default/bin/python -m pip install --upgrade pip' command.

# %%
from jupyter_dash import JupyterDash

import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd
import plotly.express as px
from jupyter_dash import JupyterDash
from dash.dependencies import Input, Output

# %%
JupyterDash.infer_jupyter_proxy_config()
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
# OSError: Unable to communicate with the jupyter_dash notebook or JupyterLab
# extension required to infer Jupyter configuration.

# %%
file_loc = "https://raw.githubusercontent.com/bhattbhavesh91/durbin-watson-test-python/master/durbin_data.csv"

df = pd.read_csv(file_loc)
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X1</th>
#       <th>X2</th>
#       <th>X3</th>
#       <th>Y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>230.1</td>
#       <td>37.8</td>
#       <td>69.2</td>
#       <td>22.1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>44.5</td>
#       <td>39.3</td>
#       <td>45.1</td>
#       <td>10.4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>17.2</td>
#       <td>45.9</td>
#       <td>69.3</td>
#       <td>9.3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>151.5</td>
#       <td>41.3</td>
#       <td>58.5</td>
#       <td>18.5</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>180.8</td>
#       <td>10.8</td>
#       <td>58.4</td>
#       <td>12.9</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
app = JupyterDash(__name__)
app.layout = html.Div([
    html.H1("JupyterDash Demo"),
    dcc.Graph(id='graph'),
    html.Label([
        "Input Variable",
        dcc.Dropdown(
            id='column-dropdown', clearable=False,
            value = df.columns[0], options=[
                {'label': c, 'value': c}
                for c in df.columns
            ])
    ]),
])
# Define callback to update graph
@app.callback(
    Output('graph', 'figure'),
    [Input("column-dropdown", "value")]
)
def update_figure(column):
    return px.scatter(
        df, x=column, y="Y",
        render_mode="webgl", title="Scatter Plot"
    )
# Run app and display result inline in the notebook
app.run_server(mode='inline')
